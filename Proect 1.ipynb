# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
import pandas as pd
con=mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="Amimonil@1",
    database='studentdb')
df=pd.read_sql_query("select * from studmarks",con)
df
# Out:
#    Name Gender  DOB  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0     N      G    0      0        0          0        0        0          0
# 1     J      M    5     55       45         56       87       21         52
# 2     S      M    4     75       96         78       64       90         61
# 3     R      M   25     25       54         89       76       95         87
# 4     J      F   12     78       96         86       63       54         89
# 5     J      F    2     58       96         78       46       96         77
# 6     A      F    5     45       87         52       89       55         89
# 7     p      F    4     55       64         61       58       75         58
# 8     R      M   25     54       76         87       56       25         56
# 9     F      F   12     55       63         89       75       78         75
# 10    M      M    2     96       46         77       83       58         83
#
#     History  Civics
# 0         0       0
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_csv("studmarks.csv")
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
df.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
df.tail()
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 5    Annu      F  05-04-1988     45       87         52       89       55
# 6   pooja      F  04-05-1987     55       64         61       58       75
# 7  Ritesh      M  25-05-1989     54       76         87       56       25
# 8   Farha      F  12-08-1990     55       63         89       75       78
# 9  Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
df.shape
# Out:
# (10, 11)

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Name         10
# Gender        2
# DOB           5
# Maths         8
# Physics       8
# Chemistry     8
# English      10
# Biology      10
# Economics     9
# History      10
# Civics       10
# dtype: int64

# %%
df['Chemistry'].unique()
# Out:
# array([56, 78, 89, 86, 52, 61, 87, 77], dtype=int64)

# %%
df['Economics'].unique()
# Out:
# array([52, 61, 87, 89, 77, 58, 56, 75, 83], dtype=int64)

# %%
#cleaning the data or check null value in dataset.
df.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %%
data=df.drop(['Chemistry','Economics'], axis=1)
data
# Out:
#        Name Gender         DOB  Maths  Physics  English  Biology  History  \
# 0      John      M  05-04-1988     55       45       87       21       89
# 1    Suresh      M  04-05-1987     75       96       64       90       58
# 2    Ramesh      M  25-05-1989     25       54       76       95       56
# 3   Jessica      F  12-08-1990     78       96       63       54       75
# 4  Jennifer      F  02-09-1989     58       96       46       96       83
# 5      Annu      F  05-04-1988     45       87       89       55       87
# 6     pooja      F  04-05-1987     55       64       58       75       64
# 7    Ritesh      M  25-05-1989     54       76       56       25       76
# 8     Farha      F  12-08-1990     55       63       75       78       63
# 9    Mukesh      M  02-09-1989     96       46       83       58       46
#
#    Civics
# 0      65
# 1       2
# 2      74
# 3      45
# 4      53
# 5      52
# 6      61
# 7      87
# 8      89
# 9      77

# %%
#corelation analysis
corelation=df.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
sns.pairplot(df)

# %%
sns.relplot(x= 'Maths', y= 'Physics', hue= 'Gender', data=df)

# %%
sns.relplot(x= 'Maths', y= 'Physics', hue= 'Name', data=df)

# %%
sns.distplot(df['Maths'])

# %%
sns.distplot(df['Physics'], bins=20)

# %%
sns.distplot(df['Economics'], bins=5)

# %%
sns.catplot(x='Maths',kind='box', data=df)

# %%
sns.catplot(x='Biology',kind='box', data=df)

# %% [markdown]
# Titanic Dataset EDA

# %%
data=pd.read_csv("Titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1 = df.dropna()
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.shape
# Out:
# (183, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
data.nunique()
# Out:
# PassengerId    183
# Survived         2
# Pclass           3
# Name           183
# Sex              2
# Age             63
# SibSp            4
# Parch            4
# Ticket         127
# Fare            93
# Cabin          133
# Embarked         3
# dtype: int64

# %%
data['PassengerId'].unique()
# Out:
# array([  2,   4,   7,  11,  12,  22,  24,  28,  53,  55,  63,  67,  76,
#         89,  93,  97,  98, 103, 111, 119, 124, 125, 137, 138, 140, 149,
#        152, 171, 175, 178, 184, 194, 195, 196, 206, 210, 216, 219, 225,
#        231, 246, 249, 252, 253, 258, 263, 264, 269, 270, 274, 276, 292,
#        293, 298, 300, 306, 308, 310, 311, 312, 319, 320, 326, 328, 330,
#        332, 333, 337, 338, 340, 341, 342, 346, 357, 367, 370, 371, 378,
#        391, 394, 395, 413, 430, 431, 435, 436, 439, 446, 450, 453, 454,
#        457, 461, 463, 474, 485, 487, 488, 493, 497, 499, 505, 506, 513,
#        516, 517, 521, 524, 537, 540, 541, 545, 551, 557, 559, 572, 573,
#        578, 582, 584, 586, 588, 592, 600, 610, 619, 622, 626, 628, 631,
#        633, 642, 646, 648, 660, 663, 672, 680, 682, 690, 691, 699, 700,
#        701, 702, 708, 711, 713, 716, 717, 718, 725, 731, 738, 742, 743,
#        746, 749, 752, 760, 764, 766, 773, 780, 782, 783, 790, 797, 803,
# ...

# %%
corelation = data.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x= 'PassengerId', y= 'Cabin', hue = 'Age', data=data)

# %%
sns.distplot(data['PassengerId'])

# %%
sns.catplot(x= 'PassengerId', y= 'Cabin', data=data)

# %% [markdown]
# Winequality Dataset

# %%
dt=pd.read_csv("Winequality.csv")
dt
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dt.shape
# Out:
# (1599, 12)

# %%
dt.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
dt.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
dt.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
dt['volatile acidity'].unique()
# Out:
# array([0.7  , 0.88 , 0.76 , 0.28 , 0.66 , 0.6  , 0.65 , 0.58 , 0.5  ,
#        0.615, 0.61 , 0.62 , 0.56 , 0.59 , 0.32 , 0.22 , 0.39 , 0.43 ,
#        0.49 , 0.4  , 0.41 , 0.71 , 0.645, 0.675, 0.685, 0.655, 0.605,
#        0.38 , 1.13 , 0.45 , 0.67 , 0.52 , 0.935, 0.29 , 0.31 , 0.51 ,
#        0.42 , 0.63 , 0.69 , 0.735, 0.725, 0.705, 0.785, 0.75 , 0.625,
#        0.3  , 0.55 , 1.02 , 0.775, 0.9  , 0.545, 0.575, 0.33 , 0.54 ,
#        1.07 , 0.695, 1.33 , 0.745, 1.04 , 0.715, 0.415, 0.34 , 0.68 ,
#        0.95 , 0.53 , 0.64 , 0.885, 0.805, 0.73 , 0.37 , 0.835, 1.09 ,
#        0.57 , 0.44 , 0.635, 0.82 , 0.48 , 1.   , 0.21 , 0.35 , 0.975,
#        0.26 , 0.87 , 0.18 , 0.27 , 0.2  , 0.36 , 0.83 , 0.46 , 0.47 ,
#        0.77 , 0.815, 0.795, 0.665, 0.765, 0.24 , 0.85 , 0.84 , 0.96 ,
#        0.78 , 0.23 , 0.315, 0.365, 0.25 , 0.825, 0.72 , 0.595, 0.585,
#        0.915, 0.755, 0.845, 1.24 , 0.8  , 0.98 , 1.185, 0.92 , 1.035,
# ...

# %%
dt.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
dt.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
dt.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
corelation = data.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

# %%
sns.pairplot(data)
